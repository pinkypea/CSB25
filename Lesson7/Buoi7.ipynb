# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("ads_data.csv")
df
# Out:
#     Advertising Cost (USD)  Sales Revenue (USD)
# 0                      784          5167.683485
# 1                      659          4736.040926
# 2                      729          4799.105662
# 3                      292          2307.039663
# 4                      935          5917.849078
# 5                      863          5753.385395
# 6                      807          5348.687786
# 7                      459          3390.113449
# 8                      109           841.300662
# 9                      823          5324.660476
# 10                     377          2713.570097
# 11                     854          5926.878257
# 12                     904          5857.388520
# 13                     699          4703.472963
# 14                     170          1812.548089
# 15                     572          4239.005826
# 16                     700          4813.288008
# 17                     496          3505.853018
# 18                     414          2768.344399
# 19                     805          5609.094454
# 20                     586          4373.496809
# 21                     651          4292.096547
# 22                     187          1657.077307
# 23                     274          2051.498892
# 24                     700          4482.839881
# 25                     949          6321.947199
# 26                     777          5084.827333
# 27                     637          4166.847529
# 28                     945          6369.142270
# 29                     172          1145.359044
# 30                     877          5811.706125
# 31                     215          1783.750933
# 32                     855          5602.105208
# 33                     809          5315.868804
# 34                     947          6271.727505

# %%
df.plot.scatter (
    x = "Advertising Cost (USD)",
    y = "Sales Revenue (USD)"
)
plt.show()

# %%
# Tạo mô hình hồi quy tuyến tính
model = LinearRegression()

x = df.iloc[:, 0:1] # chỉ định x là cột Advertising Cost
y = df.iloc[:, 1:2] # chỉ định y là cột Sales Revenue

# Huấn luyện mô hình
model.fit(x, y)
# Out:
# LinearRegression()

# %%
# Hệ số góc a
model.coef_
# Out:
# array([[6.14733189]])

# %%
# Hệ số chặn b
model.intercept_
# Out:
# array([423.64529827])

# %%
df.plot.scatter (
    x = "Advertising Cost (USD)",
    y = "Sales Revenue (USD)"
)

# y = ax + b
x_line = np.linspace(x.min(), x.max(), 100).reshape(-1, 1)
y_line = model.coef_[0] * x_line + model.intercept_
plt.plot(x_line, y_line, color='red', label='Best fit line')
plt.show()

# %%
model.predict(pd.DataFrame([600]))
# Out:
# c:\Users\Admin\Desktop\CSA15\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[4112.04443118]])

# %%
model.predict(pd.DataFrame([1000, 2000, 3000]))
# Out:
# c:\Users\Admin\Desktop\CSA15\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[ 6570.97718645],
#        [12718.30907463],
#        [18865.64096281]])

# %%
# Kiểm tra hệ số tương quan
df["Sales Revenue (USD)"].corr(df["Advertising Cost (USD)"])
# Out:
# np.float64(0.9940740630509901)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (28, 1) (28, 1)
# (7, 1) (7, 1)

# %%
new_model = LinearRegression()
new_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = new_model.predict(x_test)

# %%
new_model.coef_, new_model.intercept_
# Out:
# (array([[6.07996297]]), array([477.1814076]))

# %%
# Tính lỗi của mô hình
mse = mean_squared_error(y_test, y_pred)
mse
# Out:
# 53852.56448015925

# %%
# Đánh giá độ khớp của mô hình
r2 = r2_score(y_test, y_pred)
r2
# Out:
# 0.9696953486116257

# %%
df.plot.scatter (
    x = "Advertising Cost (USD)",
    y = "Sales Revenue (USD)"
)

# y = ax + b
x_line = np.linspace(x.min(), x.max(), 100).reshape(-1, 1)
y_line = model.coef_[0] * x_line + model.intercept_
plt.plot(x_line, y_line, color='red', label='Best fit line')

new_y_line = new_model.coef_[0] * x_line + new_model.intercept_
plt.plot(x_line, new_y_line, color = 'green', label='New best fit line')
plt.show()
