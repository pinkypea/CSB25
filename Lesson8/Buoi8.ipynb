# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("ads_data_full.csv")
df.head()
# Out:
#    Advertising Cost (USD)  Sales Revenue (USD)  Social Media Engagements  \
# 0                     784          5167.683485                       165
# 1                     659          4736.040926                       288
# 2                     729          4799.105662                       248
# 3                     292          2307.039663                       275
# 4                     935          5917.849078                       472
#
#    Website Traffic
# 0             6899
# 1             2245
# 2             1325
# 3             2124
# 4             4391

# %%
df.shape
# Out:
# (35, 4)

# %%
figure, axes = plt.subplots(1, 3, figsize=(12, 4))
df.plot.scatter(
    x = "Advertising Cost (USD)",
    y = "Sales Revenue (USD)",
    ax = axes[0]
)
df.plot.scatter(
    x = "Social Media Engagements",
    y = "Sales Revenue (USD)",
    ax = axes[1]
)
df.plot.scatter(
    x = "Website Traffic",
    y = "Sales Revenue (USD)",
    ax = axes[2]
)

plt.tight_layout()
plt.show()
